# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading datasets

# %%
df_christies = pd.read_csv('whatmakesdata/christies.csv')
df_sothebys = pd.read_csv('whatmakesdata/SothebysData_clean.csv')

# %% [markdown]
# ### fixing the year column for the christies dataframe

# %%
# Function to fix closeYear column
def fix_year(year):
    if pd.isna(year):  # Handle NaN values
        return None
    year = int(year)  # Convert to integer
    if year > 2000:  # Already in four-digit format
        return year
    elif year >= 50:  # Assume 1950-1999
        return 1900 + year
    else:  # Assume 2000-2049
        return 2000 + year


# Apply function to transform closeYear properly
df_christies["sale_year"] = df_christies["closeYear"].apply(fix_year)

# Drop unnecessary columns
df_christies.drop(columns=["closeYear"], inplace=True)

# Save cleaned dataset
df_christies.to_csv("christies_cleaned.csv", index=False)

# Check result
print(df_christies[["sale_year"]].head())
# Out:
#    sale_year
# 0       2016
# 1       2017
# 2       2013
# 3       2012
# 4       2018

# %% [markdown]
# ### renaming the columns accoridngly and merging the datasets

# %%
# Standardize column names
df_sothebys.rename(columns={
    'Title': 'title', 'Artist': 'artist', 'Currency': 'currency',
    'Selling Price': 'price', 'low_estimate': 'low_estimate',
    'high_estimate': 'high_estimate', 'Sold': 'sold',
    'Auction Name': 'auction_title', 'Date': 'sale_year'
}, inplace=True)

df_christies.rename(columns={
    'Art Title': 'title', 'Artist': 'artist', 'Currency': 'currency',
    'price': 'price', 'low_estimate': 'low_estimate',
    'high_estimate': 'high_estimate', 'Sold': 'sold',
    'Auction Title': 'auction_title', 'sale_year': 'sale_year'
}, inplace=True)


# Ensure sale_year is integer
df_sothebys['sale_year'] = pd.to_numeric(
    df_sothebys['sale_year'], errors='coerce')
df_christies['sale_year'] = pd.to_numeric(
    df_christies['sale_year'], errors='coerce')

# Drop unnecessary columns
df_sothebys.drop(columns=['Unnamed: 0', 'Signed',
                 'Category', 'Image'], inplace=True, errors='ignore')
df_christies.drop(columns=['DoC', 'Dimentions', 'Alive?', 'close date',
                  'closeMonth', 'popularity'], inplace=True, errors='ignore')

# Merge datasets
df_merged = pd.concat([df_sothebys, df_christies], ignore_index=True)

# Save merged dataset
df_merged.to_csv('merged_auction_data.csv', index=False)

# Display merged dataset info
df_merged
# Out:
#                                                artist  \
# 0     French School, 18th Century, A white greyhound
# 1                         François Léon Prieur-Bardin
# 2                                        Stefano Ussi
# 3                                      Ludwig Deutsch
# 4                                     Eugène Girardet
# ...                                               ...
# 2775                           walter richard sickert
# 2776                                 robert delaunay
# 2777                                     henry moore
# 2778                                      walter gay
# 2779                          mitelli, giuseppe maria
#
#                                                  title Location currency  \
# 0      Ecole française du XVIIIe siècle, Lévrier blanc    Paris      USD
# 1                                     On the Bosphorus   London      USD
# 2                                     A Moroccan Guard   London      USD
# 3                                    Before the Mosque   London      USD
# 4                                          The Caravan   London      USD
# ...                                                ...      ...      ...
# 2775                  The Façade of St. Mark's, Venice      NaN      USD
# 2776                                 Manège de cochons      NaN      USD
# 2777               Two Piece Reclining Figure: Armless      NaN      USD
# 2778                                Intérieur Parisien      NaN      USD
# 2779                                               NaN      NaN      USD
#
#       sale_year  sold      price  low_estimate  high_estimate  \
# 0        2022.0     0       0.00       5550.50        7770.70
# 1        2022.0     1   62830.65      39367.57       52490.10
# 2        2022.0     1    7936.50       5249.01        7873.51
# 3        2022.0     0       0.00     262450.50      393675.75
# 4        2022.0     0       0.00      65612.62       91857.67
# ...         ...   ...        ...           ...            ...
# 2775     2012.0     1   25000.00      25000.00       37500.00
# 2776     2021.0     1  651000.00     525000.00      840000.00
# 2777     2018.0     1  985937.50     625000.00      875000.00
# 2778     2018.0     1    8125.00       4000.00        6000.00
# 2779     2019.0     1   17187.50       2500.00        3750.00
#
#                                           auction_title   Birth   Death   Age  \
# 0                                               ANIMALS     NaN     NaN   NaN
# 1                                  The Orientalist Sale     NaN     NaN   NaN
# 2                                  The Orientalist Sale     NaN     NaN   NaN
# 3                                  The Orientalist Sale     NaN     NaN   NaN
# 4                                  The Orientalist Sale     NaN     NaN   NaN
# ...                                                 ...     ...     ...   ...
# 2775              MODERN BRITISH AND IRISH ART DAY SALE  1860.0  1942.0  82.0
# 2776  OEUVRES MODERNES SUR PAPIER / ART IMPRESSIONNI...  1885.0  1941.0  56.0
# 2777          IMPRESSIONIST AND MODERN ART EVENING SALE  1898.0  1986.0  88.0
# 2778                                American Art Online  1856.0  1937.0  81.0
# 2779                           THE ROYAL HOUSE OF SAVOY  1634.0  1718.0  84.0
#
#       Est Accuracy
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 2775          -1.0
# 2776           0.0
# 2777           1.0
# 2778           1.0
# 2779           1.0
#
# [2780 rows x 14 columns]

# %% [markdown]
# #### removing rows where there is no title and unnecessary columns

# %%
df_merged.dropna(subset=['title'], inplace=True)

# %%
df_merged.drop(columns=['Location',  'Birth', 'Death',
               'Age', 'Est Accuracy'], inplace=True)  # 'sold',

# Check if all values in the 'currency' column are 'USD'
if df_merged['currency'].nunique() == 1 and df_merged['currency'].iloc[0] == 'USD':
    df_merged.drop(columns=['currency'], inplace=True)

# Save the updated dataframe
df_merged.to_csv('merged_auction_data.csv', index=False)

# %% [markdown]
# #### check why some rows have currency value Error

# %%
# Add a source column to indicate the origin of each row
df_sothebys['source'] = 'sothebys'
df_christies['source'] = 'christies'

# Merge datasets again with the source column
df_merged_with_source = pd.concat(
    [df_sothebys, df_christies], ignore_index=True)

# Filter rows where currency is not USD
non_usd_rows = df_merged_with_source[df_merged_with_source['currency'] != 'USD']

# Check the source of these rows
print(non_usd_rows['source'].value_counts())
print(len(non_usd_rows['source'].value_counts())*100/len(df_merged))
# Out:
# source
# sothebys    97
# Name: count, dtype: int64
# 0.036036036036036036

# %% [markdown]
# We see here that all the values with Error in their currency column come from the Sothebys dataset , we have 2 options here, either drop them completely , since we have only 97 such values which represents a mere 0.036% of the whole dataset, or try a different approach to fill them up , since the precentage is too low , we can go ahead and drop these rows

# %%
# Drop rows where the currency column has 'Error'
df_merged = df_merged[df_merged['currency'] != 'Error']

# Save the updated dataframe
df_merged.to_csv('merged_auction_data_cleaned.csv', index=False)

# Display the updated dataframe info
df_merged
# Out:
#                                                artist  \
# 0     French School, 18th Century, A white greyhound
# 1                         François Léon Prieur-Bardin
# 2                                        Stefano Ussi
# 3                                      Ludwig Deutsch
# 4                                     Eugène Girardet
# ...                                               ...
# 2774                                   james turrell
# 2775                           walter richard sickert
# 2776                                 robert delaunay
# 2777                                     henry moore
# 2778                                      walter gay
#
#                                                  title currency  sale_year  \
# 0      Ecole française du XVIIIe siècle, Lévrier blanc      USD     2022.0
# 1                                     On the Bosphorus      USD     2022.0
# 2                                     A Moroccan Guard      USD     2022.0
# 3                                    Before the Mosque      USD     2022.0
# 4                                          The Caravan      USD     2022.0
# ...                                                ...      ...        ...
# 2774                                      Hologram #10      USD     2017.0
# 2775                  The Façade of St. Mark's, Venice      USD     2012.0
# 2776                                 Manège de cochons      USD     2021.0
# 2777               Two Piece Reclining Figure: Armless      USD     2018.0
# 2778                                Intérieur Parisien      USD     2018.0
#
#       sold      price  low_estimate  high_estimate  \
# 0        0       0.00       5550.50        7770.70
# 1        1   62830.65      39367.57       52490.10
# 2        1    7936.50       5249.01        7873.51
# 3        0       0.00     262450.50      393675.75
# 4        0       0.00      65612.62       91857.67
# ...    ...        ...           ...            ...
# 2774     1  187500.00     150000.00      250000.00
# 2775     1   25000.00      25000.00       37500.00
# 2776     1  651000.00     525000.00      840000.00
# 2777     1  985937.50     625000.00      875000.00
# 2778     1    8125.00       4000.00        6000.00
#
#                                           auction_title
# 0                                               ANIMALS
# 1                                  The Orientalist Sale
# 2                                  The Orientalist Sale
# 3                                  The Orientalist Sale
# 4                                  The Orientalist Sale
# ...                                                 ...
# 2774      POST-WAR & CONTEMPORARY ART AFTERNOON SESSION
# 2775              MODERN BRITISH AND IRISH ART DAY SALE
# 2776  OEUVRES MODERNES SUR PAPIER / ART IMPRESSIONNI...
# 2777          IMPRESSIONIST AND MODERN ART EVENING SALE
# 2778                                American Art Online
#
# [2678 rows x 9 columns]

# %%
df = pd.read_csv('merged_auction_data_cleaned.csv')

# %% [markdown]
# #### Checking why some prices have values of 0

# %%
# Filter rows where price is 0
zero_price_rows = df[df['price'] == 0]

# Print the rows
print(zero_price_rows)

# Print the length of these rows
print(f"Number of rows with price 0: {len(zero_price_rows)}")

# Print the percentage of these rows in the whole dataset
percentage_zero_price = (len(zero_price_rows) / len(df)) * 100
print(f"Percentage of rows with price 0: {percentage_zero_price:.2f}%")
# Out:
#                                                artist  \
# 0     French School, 18th Century, A white greyhound
# 3                                      Ludwig Deutsch
# 4                                     Eugène Girardet
# 13                                    William Simpson
# 14                                     Carlos Abascal
# ...                                               ...
# 1873                             sir eduardo paolozzi
# 1912                                  gunther gerzso
# 2357                                   lucio fontana
# 2550                                  howard hodgkin
# 2596                                     andy warhol
#
#                                                  title currency  sale_year  \
# 0      Ecole française du XVIIIe siècle, Lévrier blanc      USD     2022.0
# 3                                    Before the Mosque      USD     2022.0
# 4                                          The Caravan      USD     2022.0
# 13                  Jerusalem from the Mount of Olives      USD     2022.0
# 14                                  The Beach, Tangier      USD     2022.0
# ...                                                ...      ...        ...
# 1873                                 Castel Lagopesole      USD     2022.0
# 1912                               Tihuanacu Revisited      USD     2022.0
# 2357                     [Concetto spaziale, Teatrino]      USD     2020.0
# 2550                                       IMAX Cinema      USD     2022.0
# 2596                                     Fran Lebowitz      USD     2022.0
#
#       sold  price  low_estimate  high_estimate  \
# 0        0    0.0       5550.50        7770.70
# 3        0    0.0     262450.50      393675.75
# 4        0    0.0      65612.62       91857.67
# 13       0    0.0     104980.20      157470.30
# 14       0    0.0      19683.79       26245.05
# ...    ...    ...           ...            ...
# 1873     0    0.0       5000.00        7500.00
# 1912     0    0.0      25000.00       35000.00
# 2357     0    0.0     157500.00      210000.00
# 2550     0    0.0      31250.00       43750.00
# 2596     0    0.0       2000.00        3000.00
#
#                               auction_title
# 0                                   ANIMALS
# 3                      The Orientalist Sale
# 4                      The Orientalist Sale
# 13                     The Orientalist Sale
# 14                     The Orientalist Sale
# ...                                     ...
# 1873  MODERN BRITISH AND IRISH ART DAY SALE
# 1912              Latin American Art Online
# 2357                 THINKING ITALIAN MILAN
# 2550  MODERN BRITISH AND IRISH ART DAY SALE
# 2596                The Andy Warhol Diaries
#
# [327 rows x 9 columns]
# Number of rows with price 0: 327
# Percentage of rows with price 0: 12.21%

# %%
# Filter rows where price is 0
zero_price_rows = df[df['price'] == 0]

# Count the values in the 'sold' column for these rows
sold_counts = zero_price_rows['sold'].value_counts()

# Print the counts
print(sold_counts)
print(len(df[df['sold'] == 0]))
# Out:
# sold
# 0    327
# Name: count, dtype: int64
# 327

# %% [markdown]
# so we see that the values with 0 in price also happen to have 0 in the value for sold , which means that they're unsold, so we have to drop since we're only interested in those who got sold . Interestingly , all the art works yet to be sold also have 0 in price whcih means that elimanting them in the best option .

# %%
# Drop rows where price is 0
df = df[df['price'] != 0]

# Drop the 'sold' column
df.drop(columns=['sold', 'currency'], inplace=True)

# Save the updated dataframe
df.to_csv('final_df.csv', index=False)

# Display the updated dataframe info
df
# Out:
#                            artist                                title  \
# 1     François Léon Prieur-Bardin                     On the Bosphorus
# 2                    Stefano Ussi                     A Moroccan Guard
# 5                 European School                         The Musician
# 6                  Alberto Pasini            The Yesil Mosque in Bursa
# 7                    René Legrand         Halt by an Inn, North Africa
# ...                           ...                                  ...
# 2673               james turrell                          Hologram #10
# 2674       walter richard sickert     The Façade of St. Mark's, Venice
# 2675             robert delaunay                     Manège de cochons
# 2676                 henry moore   Two Piece Reclining Figure: Armless
# 2677                  walter gay                    Intérieur Parisien
#
#       sale_year      price  low_estimate  high_estimate  \
# 1        2022.0   62830.65      39367.57       52490.10
# 2        2022.0    7936.50       5249.01        7873.51
# 5        2022.0    4629.63       2624.50        3936.76
# 6        2022.0   99206.29      78735.15      104980.20
# 7        2022.0    1653.44       2624.50        3936.76
# ...         ...        ...           ...            ...
# 2673     2017.0  187500.00     150000.00      250000.00
# 2674     2012.0   25000.00      25000.00       37500.00
# 2675     2021.0  651000.00     525000.00      840000.00
# 2676     2018.0  985937.50     625000.00      875000.00
# 2677     2018.0    8125.00       4000.00        6000.00
#
#                                           auction_title
# 1                                  The Orientalist Sale
# 2                                  The Orientalist Sale
# 5                                  The Orientalist Sale
# 6                                  The Orientalist Sale
# 7                                  The Orientalist Sale
# ...                                                 ...
# 2673      POST-WAR & CONTEMPORARY ART AFTERNOON SESSION
# 2674              MODERN BRITISH AND IRISH ART DAY SALE
# 2675  OEUVRES MODERNES SUR PAPIER / ART IMPRESSIONNI...
# 2676          IMPRESSIONIST AND MODERN ART EVENING SALE
# 2677                                American Art Online
#
# [2351 rows x 7 columns]

# %% [markdown]
# ### Reading cleaned merged df

# %%
df = pd.read_csv('final_df.csv')
df
# Out:
#                            artist                                title  \
# 0     François Léon Prieur-Bardin                     On the Bosphorus
# 1                    Stefano Ussi                     A Moroccan Guard
# 2                 European School                         The Musician
# 3                  Alberto Pasini            The Yesil Mosque in Bursa
# 4                    René Legrand         Halt by an Inn, North Africa
# ...                           ...                                  ...
# 2346               james turrell                          Hologram #10
# 2347       walter richard sickert     The Façade of St. Mark's, Venice
# 2348             robert delaunay                     Manège de cochons
# 2349                 henry moore   Two Piece Reclining Figure: Armless
# 2350                  walter gay                    Intérieur Parisien
#
#       sale_year      price  low_estimate  high_estimate  \
# 0        2022.0   62830.65      39367.57       52490.10
# 1        2022.0    7936.50       5249.01        7873.51
# 2        2022.0    4629.63       2624.50        3936.76
# 3        2022.0   99206.29      78735.15      104980.20
# 4        2022.0    1653.44       2624.50        3936.76
# ...         ...        ...           ...            ...
# 2346     2017.0  187500.00     150000.00      250000.00
# 2347     2012.0   25000.00      25000.00       37500.00
# 2348     2021.0  651000.00     525000.00      840000.00
# 2349     2018.0  985937.50     625000.00      875000.00
# 2350     2018.0    8125.00       4000.00        6000.00
#
#                                           auction_title
# 0                                  The Orientalist Sale
# 1                                  The Orientalist Sale
# 2                                  The Orientalist Sale
# 3                                  The Orientalist Sale
# 4                                  The Orientalist Sale
# ...                                                 ...
# 2346      POST-WAR & CONTEMPORARY ART AFTERNOON SESSION
# 2347              MODERN BRITISH AND IRISH ART DAY SALE
# 2348  OEUVRES MODERNES SUR PAPIER / ART IMPRESSIONNI...
# 2349          IMPRESSIONIST AND MODERN ART EVENING SALE
# 2350                                American Art Online
#
# [2351 rows x 7 columns]

# %% [markdown]
# #### convert sale_year from decimal to normal year

# %%
df['sale_year'] = df['sale_year'].astype(int)

# %% [markdown]
# #### check for missing values and duplicates

# %%
# Check for missing values
df.isnull().sum()
# Out:
# artist           0
# title            0
# sale_year        0
# price            0
# low_estimate     0
# high_estimate    0
# auction_title    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['artist', 'title', 'sale_year', 'price', 'low_estimate',
#        'high_estimate', 'auction_title'],
#       dtype='object')

# %%
# Check for duplicates
duplicates = df[df.duplicated()]
print(duplicates)
print(f"Number of duplicate rows: {len(duplicates)}")
# Out:
#                                    artist  \
# 736                        EDWARD ALCOCK
# 737           FRANCESCO ZUCCARELLI, R.A.
# 738      MANNER OF WILLIAM JONES OF BATH
# 739         ENGLISH SCHOOL, 18TH CENTURY
# 740   FOLLOWER OF JEAN-BAPTISTE SANTERRE
# ...                                   ...
# 821            WILLEM CORNELISZ. DUYSTER
# 1646                john frederick lewis
# 1980                       kazuo shiraga
# 1990                        marc chagall
# 2068                           paul klee
#
#                                                   title  sale_year      price  \
# 736    PORTRAIT OF WALTER KING (D. 1792) OF NAISH HO...       2019    6561.26
# 737    DIANA AND CALLISTO, WITH NYMPHS RESTING FROM ...       2019   19683.79
# 738    STILL LIFE WITH MIXED FRUIT IN A BASKET AND A...       2019    2460.47
# 739    A SPORTING STILL LIFE WITH A GREYHOUND SURROU...       2019    3280.63
# 740    PORTRAIT OF A LADY, THREE-QUARTER-LENGTH, IN ...       2019    4264.82
# ...                                                 ...        ...        ...
# 821                          A young officer in profile       2019   39367.57
# 1646  Sir Edwin Landseerwith a ghillie fishing for s...       2016   45312.50
# 1980                                  Chizosei Shomenko       2012  656250.00
# 1990                                       La tentation       2013   69062.50
# 2068                               Ausblick aus e. Wald       2018  225000.00
#
#       low_estimate  high_estimate  \
# 736            0.0            0.0
# 737            0.0            0.0
# 738            0.0            0.0
# 739            0.0            0.0
# 740            0.0            0.0
# ...            ...            ...
# 821            0.0            0.0
# 1646       37500.0        62500.0
# 1980      420000.0       630000.0
# 1990       31250.0        43750.0
# 2068      200000.0       300000.0
#
#                                           auction_title
# 736                          STYLE: Private Collections
# 737                          STYLE: Private Collections
# 738                          STYLE: Private Collections
# 739                          STYLE: Private Collections
# 740                          STYLE: Private Collections
# ...                                                 ...
# 821                                         Old Masters
# 1646  VICTORIAN, PRE-RAPHAELITE AND BRITISH IMPRESSI...
# 1980                                   ART CONTEMPORAIN
# 1990                IMPRESSIONIST/MODERN WORKS ON PAPER
# 2068        IMPRESSIONIST AND MODERN ART WORKS ON PAPER
#
# [90 rows x 7 columns]
# Number of duplicate rows: 90

# %%
from scipy.stats import boxcox
df = df.drop_duplicates()
